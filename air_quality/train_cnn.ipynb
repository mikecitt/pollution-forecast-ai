# %% [markdown]
# Import section

# %%
import pandas as pd
import os
import numpy as np
import keras

from pandas import DataFrame
from math import sqrt
from numpy import split
from numpy import array
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import ConvLSTM2D, Conv1D
from keras.layers import MaxPooling1D
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Activation

# %% [markdown]
# Constants

# %%
FILE_NAME = 'vegas.csv'

# %% [markdown]
# Loading dataset

# %%
df = pd.read_csv(os.path.join(FILE_NAME), header=0, index_col=0)
df.index = pd.to_datetime(df.index)
df = df.sort_values('date_local', ascending=True)
df['aqi'].plot()
pyplot.show()
total = len(df)
print(total, " entries")
# Out:
# 6007  entries

# %% [markdown]
# Conversion to supervised learning

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
FORECAST_STEP = 7
PREVIOUS_STEP = 14
values = df.values
# number of features equels to number of columns - independent feature
n_features = len(df.columns)
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, PREVIOUS_STEP, FORECAST_STEP)
# print(reframed.head())

# %%
# split into train and test sets
values = reframed.values
n_train = int(len(values) * 0.8)
train = values[:n_train, :]
test = values[n_train:, :]
# split train into train and val sets
n_val_train = int(len(train) * 0.8)
val = train[n_val_train:, :]
train = train[:n_val_train, :]
# split into input and outputs

n_inputs = n_features * PREVIOUS_STEP
n_outputs = n_features * FORECAST_STEP

train_X, train_y = train[:, :n_inputs], train[:, np.array([i + n_inputs for i in range(n_features - 1, n_outputs, n_features)])]
val_X, val_y = val[:, :n_inputs], val[:, np.array([i + n_inputs for i in range(n_features - 1, n_outputs, n_features)])]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], PREVIOUS_STEP, n_features))

val_X = val_X.reshape((val_X.shape[0], PREVIOUS_STEP, n_features))

test_X, test_y = test[:, :n_inputs], test[:, np.array([i + n_inputs for i in range(n_features - 1, n_outputs, n_features)])]

print(train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape)
# Out:
# (3831, 14, 4) (3831, 7) (958, 14, 4) (958, 7) (1198, 56) (1198, 7)

# %%
opt = keras.optimizers.Adam(learning_rate=0.0001)
# design network
model = Sequential()

model.add(Conv1D(filters=64, kernel_size=6, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(FORECAST_STEP))
model.add(Activation('linear'))
model.compile(loss='mse', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y), verbose=1, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/150
# 60/60 [==============================] - 1s 7ms/step - loss: 0.0180 - val_loss: 0.0060
# Epoch 2/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0057
# Epoch 3/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0056
# Epoch 4/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0056
# Epoch 5/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0056
# Epoch 6/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0056
# Epoch 7/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0056
# Epoch 8/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0056
# Epoch 9/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0056
# Epoch 10/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0056
# Epoch 11/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0056
# Epoch 12/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0056
# Epoch 13/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0056
# Epoch 14/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0056
# Epoch 15/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0058
# Epoch 16/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0086 - val_loss: 0.0057
# Epoch 17/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0057
# Epoch 18/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.0057
# Epoch 19/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 20/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 21/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 22/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0084 - val_loss: 0.0057
# Epoch 23/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0057
# Epoch 24/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0058
# Epoch 25/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0083 - val_loss: 0.0058
# Epoch 26/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 27/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 28/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0057
# Epoch 29/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0057
# Epoch 30/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0081 - val_loss: 0.0057
# Epoch 31/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0058
# Epoch 32/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 33/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 34/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 35/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 36/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 37/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0058
# Epoch 38/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 39/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 40/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 41/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 42/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 43/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 44/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 45/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 46/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 47/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 48/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 49/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0058
# Epoch 50/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 51/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 52/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0059
# Epoch 53/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 54/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 55/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0060
# Epoch 56/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 57/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 58/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0060
# Epoch 59/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 60/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 61/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 62/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 63/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0061
# Epoch 64/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 65/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 66/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 67/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0062
# Epoch 68/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 69/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 70/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0061
# Epoch 71/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 72/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 73/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 74/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 75/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 76/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 77/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0062
# Epoch 78/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 79/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 80/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 81/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 82/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 83/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 84/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 85/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 86/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 87/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0064
# Epoch 88/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0065
# Epoch 89/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 90/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 91/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0064
# Epoch 92/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 93/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 94/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 95/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 96/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 97/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 98/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 99/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0069
# Epoch 100/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 101/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 102/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 103/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 104/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 105/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0069
# Epoch 106/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 107/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 108/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 109/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 110/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 111/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0067
# Epoch 112/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0059 - val_loss: 0.0066
# Epoch 113/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 114/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 115/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 116/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0069
# Epoch 117/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0070
# Epoch 118/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0069
# Epoch 119/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 120/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 121/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0067
# Epoch 122/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0068
# Epoch 123/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0069
# Epoch 124/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 125/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0071
# Epoch 126/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0053 - val_loss: 0.0070
# Epoch 127/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 128/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0071
# Epoch 129/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0072
# Epoch 130/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 131/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 132/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 133/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 134/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0072
# Epoch 135/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0070
# Epoch 136/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0073
# Epoch 137/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0074
# Epoch 138/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 139/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 140/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0073
# Epoch 141/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0072
# Epoch 142/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0072
# Epoch 143/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0049 - val_loss: 0.0071
# Epoch 144/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0050 - val_loss: 0.0071
# Epoch 145/150
# 60/60 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0074
# Epoch 146/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0075
# Epoch 147/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0052 - val_loss: 0.0077
# Epoch 148/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0051 - val_loss: 0.0076
# Epoch 149/150
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0050 - val_loss: 0.0074
# Epoch 150/150
# 60/60 [==============================] - 0s 4ms/step - loss: 0.0050 - val_loss: 0.0073

# %%
def make_predictions(model, train, test, n_lag, n_seq, n_features):
    forecasts = list()

    for i in range(len(test)):
        X, y = test[i, :-(n_features * n_seq)], test[i, -(n_features * n_seq):]
        X = X.reshape((1, n_lag, n_features))
        forecast = model.predict(X, batch_size=16, verbose=0)
        forecasts.append([x for x in forecast[0, :]])
    return forecasts

# %%
def prep_data(scaler, test_X, test_y, forecasts, n_lag, n_seq, n_features, start):
    if len(test_X) - n_lag - n_seq < start:
        return
    past_data = []
    predicted = []
    groundtruth = []
    for i in range(0, n_lag * n_features, n_features):
        inv_y = np.concatenate(([test_X[start, i + n_features - 1]], test_X[start, i:i + n_features -1]))
        inv_y = scaler.inverse_transform(inv_y.reshape(1, n_features))
        past_data.append(inv_y[:,0])

    print(test_X.shape)
    for i in range(0, n_seq):
        inv_yhat = np.concatenate(([forecasts[start + n_lag][i]], test_X[start + n_lag + i, :n_features - 1]))
        inv_yhat = scaler.inverse_transform(inv_yhat.reshape(1, n_features))
        predicted.append(inv_yhat[:,0])

        ghd_y = np.concatenate(([test_y[start + n_lag][i]], test_X[start + n_lag + i, :n_features - 1]))
        ghd_y = scaler.inverse_transform(ghd_y.reshape(1, n_features))
        groundtruth.append(ghd_y[:,0])
        
    return past_data, predicted, groundtruth

# %%
def evaluate_prediction(predictions, actual, model_name , start , end):
    errors = np.array(predictions) - np.array(actual)
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print("Test Data from {} to {}".format(start, end))
    print('Mean Absolute Error: {:.2f}'.format(mae))
    print('Root Mean Square Error: {:.2f}'.format(rmse))
    print('')
    print('')

# %%
def plot_multistep(history, prediction1, groundtruth , start , end):
    pyplot.figure(figsize=(20, 4))
    y_mean = np.mean(prediction1)
    range_history = len(history)
    range_future = list(range(range_history, range_history + len(prediction1)))
    pyplot.plot(np.arange(range_history), np.array(history), label='History', marker='o')
    pyplot.plot(range_future, np.array(prediction1),label='Forecasted with CNN', marker='o')
    pyplot.plot(range_future, np.array(groundtruth),label='GroundTruth', marker='o')
    pyplot.legend(loc='upper left')
    pyplot.title("Test Data from {} to {}, Mean = {:.2f}".format(start, end, y_mean) ,  fontsize=18)
    pyplot.xlabel('Time step' ,  fontsize=18)
    pyplot.ylabel('y-value' , fontsize=18)

# %%
start = 200
forecasts = make_predictions(model, train, test, PREVIOUS_STEP, FORECAST_STEP, n_features)
past_data, predicted, groundtruth = prep_data(scaler, test_X, test_y, forecasts, PREVIOUS_STEP, FORECAST_STEP, n_features, start)
plot_multistep(past_data, predicted, groundtruth, start, start + PREVIOUS_STEP + FORECAST_STEP)
evaluate_prediction(predicted, groundtruth, 'LSTM', start + PREVIOUS_STEP, start + PREVIOUS_STEP + FORECAST_STEP)
# Out:
# (1198, 56)
# Test Data from 214 to 221
# Mean Absolute Error: 0.08
# Root Mean Square Error: 0.11
